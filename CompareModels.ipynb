# %%
import params as p
import nn

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import numpy as np
# Out:
# <style>.container { width:100% !important; }</style>

# %%
r = nn.runModel('ETHUSDROC')
# Out:
# **************** Loaded Config for ETHUSDROC ****************
# Loaded ETHUSD prices from KRAKEN via cc Rows:1979 Date:2021-01-05 00:00:00
# Last complete day close: 1042.52
# Strategy Return: 27985.09
# Market Return: 877.53
# Sortino Ratio: 4.38
# Bars in Trade: 11
# Buy Pct: 0.65
# Accuracy: 0.54
# Win Ratio: 0.54
# Avg Win: 0.30
# Avg Loss: 0.03
# Risk to Reward: 10.52
# Expectancy: 4.97
# Sharpe Ratio: 2.45
# Average Daily Return: 0.014
# SL: 0.00 TP: 0.00
# ETH/USD: Same Signal: Buy, Total PnL: 2798409.03%

# %%
e = nn.runModel('ETHUSDENS')
# Out:
# **************** Loaded Config for ETHUSDENS ****************
#
# **************** Loaded Config for ETHUSDNN1 ****************
# Loaded ETHUSD prices from KRAKEN via cc Rows:1979 Date:2021-01-05 00:00:00
# Last complete day close: 1042.52
# Loaded ETHBTC prices from KRAKEN via cc Rows:1979 Date:2021-01-05 00:00:00
# Last complete day close: 0.03256
# Strategy Return: 2768047.57
# Market Return: 1259.50
# Sortino Ratio: 8.41
# Bars in Trade: 3
# Buy Pct: 0.56
# Accuracy: 0.58
# Win Ratio: 0.60
# Avg Win: 0.07
# Avg Loss: 0.02
# Risk to Reward: 3.91
# Expectancy: 3.87
# Sharpe Ratio: 3.71
# Average Daily Return: 0.011
# SL: 0.00 TP: 0.00
# ETH/USD: Same Signal: Buy, Total PnL: 276804656.99%
#
# **************** Loaded Config for ETHUSDNN2 ****************
# Loaded ETHUSD prices from KRAKEN via cc Rows:1979 Date:2021-01-05 00:00:00
# Last complete day close: 1042.52
# Strategy Return: 10329.09
# Market Return: 848.58
# Sortino Ratio: 3.97
# Bars in Trade: 4
# Buy Pct: 0.57
# Accuracy: 0.55
# Win Ratio: 0.60
# Avg Win: 0.07
# Avg Loss: 0.03
# Risk to Reward: 2.11
# Expectancy: 2.77
# Sharpe Ratio: 2.21
# Average Daily Return: 0.008
# SL: 0.00 TP: 0.00
# ETH/USD: Same Signal: Buy, Total PnL: 1032808.98%
#
# **************** Loaded Config for ETHUSDROC ****************
# Loaded ETHUSD prices from KRAKEN via cc Rows:1979 Date:2021-01-05 00:00:00
# Last complete day close: 1042.52
# Strategy Return: 27983.02
# Market Return: 877.46
# Sortino Ratio: 4.38
# Bars in Trade: 11
# Buy Pct: 0.65
# Accuracy: 0.54
# Win Ratio: 0.54
# Avg Win: 0.30
# Avg Loss: 0.03
# Risk to Reward: 10.52
# Expectancy: 4.97
# Sharpe Ratio: 2.45
# Average Daily Return: 0.014
# SL: 0.00 TP: 0.00
# ETH/USD: Same Signal: Buy, Total PnL: 2798201.82%
#
# **************** Loaded Config for ETHUSDENS ****************
# Strategy Return: 410891.35
# Market Return: 1371.10
# Sortino Ratio: 5.84
# Bars in Trade: 4
# Buy Pct: 0.65
# Accuracy: 0.57
# Win Ratio: 0.61
# Avg Win: 0.10
# Avg Loss: 0.03
# Risk to Reward: 3.80
# Expectancy: 4.61
# Sharpe Ratio: 3.06
# Average Daily Return: 0.013
# SL: 0.00 TP: 0.00
# ETH/USD: Same Signal: Buy, Total PnL: 41089035.0%

# %%
r.tail(300).SR.prod()
# Out:
# 7.0274055318375055

# %%
e.tail(300).SR.prod()
# Out:
# 10.993963796980461

# %%
e
# Out:
#            date       open       high       low      close signal        ADX  \
# 11   2015-12-07     0.8250     0.8250    0.7829     0.7900   Sell  41.727592
# 12   2015-12-08     0.7900     0.8980    0.7796     0.7946   Sell  37.488923
# 13   2015-12-09     0.7946     0.8533    0.7610     0.8051   Sell  31.743948
# 14   2015-12-10     0.8051     0.8683    0.7797     0.8437   Sell  28.564538
# 15   2015-12-11     0.8437     0.9000    0.7700     0.8998   Sell  28.847508
# ...         ...        ...        ...       ...        ...    ...        ...
# 1863 2021-01-01   737.4500   750.0000  717.0000   730.8500    Buy  47.499555
# 1864 2021-01-02   730.8500   788.0000  717.5000   775.0100    Buy  51.378892
# 1865 2021-01-03   775.0100  1012.7000  769.4900   979.8600    Buy  58.026772
# 1866 2021-01-04   979.8600  1166.0000  888.8800  1042.5200    Buy  64.097521
# 1867 2021-01-05  1042.5200  1134.0000  975.0000  1083.1700    Buy  69.156478
#
#                PP           R1          S1  ...      ctrf        SR        DR  \
# 11       0.799300     0.815700    0.773600  ...  1.000000  1.000000       NaN
# 12       0.824067     0.868533    0.750133  ...  1.000000  1.000000  1.005823
# 13       0.806467     0.851933    0.759633  ...  1.000000  1.000000  1.013214
# 14       0.830567     0.881433    0.792833  ...  1.000000  1.000000  1.047944
# 15       0.856600     0.943200    0.813200  ...  1.000000  1.000000  1.066493
# ...           ...          ...         ...  ...       ...       ...       ...
# 1863   732.616667   748.233333  715.233333  ...  1.229042  0.991021  0.991050
# 1864   760.170000   802.840000  732.340000  ...  1.303546  1.060619  1.060423
# 1865   920.683333  1071.876667  828.666667  ...  1.649156  1.265130  1.264319
# 1866  1032.466667  1176.053333  898.933333  ...  1.754872  1.064103  1.063948
# 1867  1064.056667  1153.113333  994.113333  ...  1.823454  1.039081  1.038992
#
#                 CSR          CMR  y_pred  y_pred_val  y_pred_id  Price_Rise  \
# 11         1.000000          NaN   False    0.333333      333.0           0
# 12         1.000000     1.005823   False    0.000000        0.0           1
# 13         1.000000     1.019114   False    0.333333      333.0           1
# 14         1.000000     1.067975   False    0.333333      333.0           1
# 15         1.000000     1.138987   False    0.333333      333.0           1
# ...             ...          ...     ...         ...        ...         ...
# 1863  276948.567982   925.126582    True    1.000000     1000.0           0
# 1864  293737.036568   981.025316    True    1.000000     1000.0           1
# 1865  371615.609706  1240.329114    True    1.000000     1000.0           1
# 1866  395437.290901  1319.645570    True    1.000000     1000.0           1
# 1867  410891.349959  1371.101266    True    1.000000     1000.0           1
#
#         date_to
# 11   2015-12-08
# 12   2015-12-09
# 13   2015-12-10
# 14   2015-12-11
# 15   2015-12-12
# ...         ...
# 1863 2021-01-02
# 1864 2021-01-03
# 1865 2021-01-04
# 1866 2021-01-05
# 1867 2021-01-06
#
# [1857 rows x 38 columns]

# %%
er = pd.merge(r, e, on='date', suffixes=('_r', '_e'))
er = er[['date', 'close_r','signal_r', 'signal_e', 'SR_r', 'SR_e', 'DR_r']]
er = er.set_index('date')
er = er.loc['2020':]
er['CSR_r'] = er.SR_r.cumprod()
er['CSR_e'] = er.SR_e.cumprod()
er['CMR'] = er.DR_r.cumprod()

fig, ax = plt.subplots(figsize=(30, 15))
# ax.set_yscale('log')
fig.autofmt_xdate()
er['color_r'] = np.where(er.signal_r=='Buy', 'g', 'r')
er['color_e'] = np.where(er.signal_e=='Buy', 'g', 'r')
ax.plot(er['CSR_r'], color='g', label='ROC')
ax.plot(er['CSR_e'], color='b', label='Combo')
ax.plot(er['CMR'], color='r', label='Market Return')
ax.scatter(er.index, er.CSR_r, color=er['color_r'], s=10)
ax.scatter(er.index, er.CSR_e, color=er['color_e'], s=10)
plt.legend()
plt.grid(True)
plt.title('Strategy Performance')
plt.show()
